# %% [markdown]
# # 📘 Introdução ao n8n — Notebook Técnico e Resumido
#
# ---
#
# ## 🧠 1. O que é o n8n?
#
# n8n é uma ferramenta de **automação de workflows** open source. Permite conectar apps, serviços e APIs com pouco ou nenhum código, usando uma interface visual.
#
# ---
#
# ## ⚡ 2. Por que usar o n8n?
#
# - Conecta serviços populares (Gmail, Sheets, Slack, bancos).
# - Automação visual com **nodes** (blocos de ação).
# - Integrações prontas + personalização com código.
# - Gratuito e open source (pode ser hospedado por você).
#
# ---
#
# ## ☁️ 3. Cloud vs Self-hosted
#
# | Tipo         | Cloud (hospedado)          | Self-hosted (seu servidor)     |
# |--------------|----------------------------|--------------------------------|
# | Instalação   | Nenhuma (pronto para usar) | Você instala (Docker, VPS etc) |
# | Custo        | Pago                        | Gratuito (exceto infra)        |
# | Controle     | Limitado                   | Total                          |
# | Escalabilidade | Limitada ao plano        | Flexível                       |
#
# ---
#
# ## 🔌 4. Integrações prontas
#
# n8n possui **mais de 300 nodes** que integram com:
#
# - E-mail (Gmail, IMAP, Outlook)
# - Bancos de dados (MySQL, PostgreSQL, MongoDB)
# - Planilhas (Google Sheets, Excel)
# - Apps de produtividade (Notion, Trello, Asana)
# - Redes sociais (Twitter/X, Discord, Telegram)
# - APIs REST e GraphQL
#
# ---
#
# ## 🤖 5. Agente de IA no n8n
#
# Permite criar bots e assistentes inteligentes usando IA (ex: GPT-4). Configurado como um **Agente de IA** no n8n.
#
# ### 🔧 Componentes principais:
#
# - **Model**: o modelo de linguagem usado (ex: OpenAI GPT-4, Mistral, etc.)
# - **Prompt**: instrução inicial do agente (ex: “Você é um assistente técnico.”)
# - **Memory**: guarda contexto de mensagens anteriores no fluxo.
# - **Tools**: funções externas acessíveis à IA (ex: consultar API, buscar PDF).
# - **Hooks**: executam ações antes/depois da IA (ex: logar respostas).
# - **RAG**: IA com busca em fontes externas (docs, bancos etc.) via tools.
#
# ---
#
# ## 🔁 6. Diferença entre API e Webhook no n8n
#
# ### 📊 Definição geral
#
# #### API (ativa)
# - O n8n **envia requisições** para outro sistema.
# - Usa métodos HTTP (GET, POST...).
# - Node comum: **HTTP Request**.
#
# #### Webhook (reativa)
# - n8n **recebe requisições** externas em uma URL.
# - Ativado por eventos (ex: envio de formulário).
# - Node comum: **Webhook**.
#
# ### ⚖️ Comparativo técnico
#
# | Característica        | API (ativa)                            | Webhook (reativa)                      |
# |------------------------|----------------------------------------|----------------------------------------|
# | Quem inicia            | n8n                                    | Serviço externo                        |
# | Direção da chamada     | n8n → outro sistema                   | Outro sistema → n8n                  |
# | Uso comum              | Buscar dados, enviar info              | Disparar fluxo por evento              |
# | Exemplo n8n            | HTTP Request, Notion, Google APIs      | Webhook → recebe de Stripe ou Typeform|
# | Controle               | n8n controla                          | Controlado externamente                |
# | Latência               | Agendada ou sob demanda               | Tempo real (evento)                    |
#
# ---
#
# ## ✅ Resumo Final
#
# - Use **API** se o n8n deve **iniciar** a comunicação (ex: buscar e-mails).
# - Use **Webhook** se um evento externo deve **acionar** um fluxo (ex: alerta do Stripe).
#
# Juntos, permitem automações ricas e reativas com controle total.
